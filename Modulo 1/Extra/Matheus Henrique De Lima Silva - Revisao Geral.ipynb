# %% [markdown]
# ### Revisão Geral de tudo um pouco - - Foco em Variáveis e Boas Práticas 🐍

# %% [markdown]
# ### 📌 1. Introdução ao Python
#
# Definição do comando print()

# %% [markdown]
# **Função: Exibe mensagens na saída padrão (tela)**
#
# **Parâmetros**:
#
# valor1, valor2,...: Valores a serem impressos
#
# sep=' ': Separador entre os valores (padrão: espaço)
#
# end='\n': Caractere final (padrão: quebra de linha)

# %% [markdown]
# Exemplo:

# %%
print("Olá", "mundo!", sep="-", end="!!\n")

# %% [markdown]
# outro exemplo:

# %%
print("Olá-Mundo!!!")

# %% [markdown]
# ### 🔢 2. Variáveis e Tipos de Dados
#
# O que são variáveis?
#
#
# 👉 "Caixinhas" que guardam informações.

# %%
# Exemplos:
nome = "Ana"           # Texto (string)
idade = 17             # Número inteiro (int)
altura = 1.65          # Número decimal (float)
estudante = True       # Verdadeiro/Falso (bool)

# %% [markdown]
# **Função:**
#
# Armazenar dados na memória para uso posterior
#
# **Características:**
#
# Dinamicamente tipada (não declara tipo)
#
# Case sensitive (idade ≠ Idade ≠ IDADE)
#
# Podem ser reatribuídas

# %% [markdown]
# ### Boas Práticas para Nomeação de Variáveis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Exemplos de Boas Práticas:

# %%
# 👍 Recomendado
nome_completo = "Maria Silva"
idade = 17
nota_media = 8.5
eh_aprovado = True

# 👎 Evitar
nm = "Maria Silva"  # Pouco descritivo
Idade = 17          # Começa com maiúscula
notaMedia = 8.5     # Notação camelCase (comum em Java/JS)

# %% [markdown]
# ### ➕ 3. Operadores Básicos - Definições

# %% [markdown]
# Operadores Aritméticos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Operadores de Comparação

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🎮 4. Input do Usuário - Definição

# %% [markdown]
# **Função: Lê uma linha da entrada padrão (teclado)**
#
# **Retorno: Sempre retorna uma string (texto)**
#
# **Conversão: Necessário converter para outros tipos**

# %%
nome = input("Digite seu nome :")

print(nome)

# %% [markdown]
# ### 🤔 5. Estruturas Condicionais - Definições

# %% [markdown]
# **Bloco if**
#
# **Regras Importantes:**
#
# Dois pontos (:) no final da condição
#
# Indentação obrigatória (4 espaços ou tab)
#
# elif e else são opcionais

# %% [markdown]
# Exemplo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Exemplo prático

# %%
nota = float(input("Digite sua nota: "))

if nota >= 9.0:
    conceito = "A"
elif nota >= 7.0:
    conceito = "B"
elif nota >= 5.0:
    conceito = "C"
else:
    conceito = "D"

print(f"Seu conceito é {conceito}")

# %% [markdown]
# ### 💡 Boas Práticas Extras

# %% [markdown]
# 1. Inicialize variáveis: Atribua valor inicial antes de usar

# %%
contador = 0  # 👍 Melhor que só declarar depois

# %% [markdown]
# 2. Evite nomes reservados:

# %%
# 👎 Evitar
list = [1, 2, 3]  # Sobrescreve a função list()

# %% [markdown]
# 3. Comentários explicativos:

# %%
# Calcula área do círculo (πr²)
pi = 3.14159
raio = 120
area = pi * raio ** 2

# %% [markdown]
# ## Conclusão:

# %% [markdown]
# ![image.png](attachment:image.png)
