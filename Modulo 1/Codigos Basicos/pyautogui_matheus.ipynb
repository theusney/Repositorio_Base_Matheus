# %%
# importei o pyautogui e apelidei de aut
import pyautogui as aut

aut.press("Win")
aut.write("Bloco de notas",interval=0.4)    # aqui dei um tempo antes da maquina escrever
aut.press("Enter")
aut.sleep(1)                               # dei um descanso pra maquina 
aut.press("Enter")
aut.write("Neymar",interval=0.5)
aut.moveTo(1385,66)                         # ajustei a maquina para mecher no mouse
aut.click()

# %%
aut.mouseInfo()                  #para pegar a cordenada

# %%
aut.press("Win")
aut.write("Google Chrome",interval=0.4)                                         # programei ele para abrir o google acessar o youtube e entrar em um video do Neymar 
aut.press("Enter")
aut.sleep(2)
aut.moveTo(956,596)
aut.click()
aut.sleep(2)
aut.moveTo(501,62)
aut.click()
aut.write("Youtube", interval=0.5)
aut.press("Enter")
aut.sleep(2)
aut.moveTo(277,319)
aut.click()
aut.sleep(2)
aut.moveTo(699,115)
aut.click()
aut.write("Neymar Skills", interval=0.5)
aut.press("Enter")
aut.sleep(2)
aut.moveTo(792,336)
aut.click()
aut.sleep(2)
aut.moveTo(1506,573)
aut.click()
aut.moveTo(1426,990)
aut.click()
aut.press(2)
aut.moveTo(362,657)
aut.click()
aut.press("Enter")
aut.moveTo(1294,516)
aut.click()
aut.write("")

# %%
import pyautogui as aut

aut.press("Win")
aut.write("Google Chrome",interval=0.4)                                         # programei ele para mandar um email com uma mensagem e com uma imagem para uma pessoa
aut.press("Enter")
aut.sleep(2)
aut.moveTo(956,596)
aut.click()
aut.sleep(2)
aut.moveTo(501,62)
aut.click()
aut.write("Neymar JR", interval=0.5)                                            # pedi pra ele digitar neymar na barra de pesquisa                            
aut.press("Enter")
aut.sleep(2)
aut.moveTo(342,211)
aut.click()
aut.sleep(2)
aut.moveTo(1140,417)
aut.click()
aut.sleep(2)
aut.rightClick(1506,573)                                                      #Botão direito do mouse
aut.sleep(2)
aut.click(1594,410)                                                        #botão Esquedo do mouse
aut.sleep(2)
aut.moveTo(797,973)
aut.click()
aut.sleep(2)
aut.moveTo(290,13)
aut.click()
aut.sleep(2)
aut.moveTo(1718,119)
aut.click()
aut.sleep(2)
aut.moveTo(161,188)
aut.click()
aut.sleep(2)
aut.write("zyzzfurios@gmail.com",interval=0.5)                                     #pedi pra ele por esse email
aut.press("Enter")
aut.moveTo(1426,990)
aut.click()
aut.sleep(2)
aut.moveTo(362,657)
aut.click()
aut.press("Enter")
aut.moveTo(1294,516)
aut.click()
aut.write("O principe que não virou rei")                                          #e digitar essa msg no assunto
aut.sleep(1)
aut.moveTo(1336,1003)
aut.click()

# %%
import pyautogui as aut

aut.press("Win")
aut.write("Google Chrome",interval=0.4)                                        
aut.press("Enter")
aut.sleep(2)
aut.moveTo(956,596)
aut.click()
aut.sleep(2)
aut.moveTo(501,62)
aut.click()
aut.write("Instagram", interval=0.5)                                                                    
aut.press("Enter")
aut.sleep(2)
aut.moveTo(1279,111)
aut.click()
aut.sleep(2)
aut.moveTo(967,380)
aut.click()
aut.sleep(2)
aut.write("08_theusz", interval= 0.3)
aut.moveTo(839,428)
aut.click()
aut.sleep(2)
aut.write("47052266m" , interval=0.5)
aut.press("Enter")
aut.sleep(5)
aut.moveTo(78,444)
aut.click()
aut.sleep(5)
aut.moveTo(268,493)
aut.click()
aut.sleep(2)
aut.moveTo(655,992)
aut.click()
aut.write("salve fiot, voce e zica" , interval=0.5)
aut.press("Enter")

# %%
aut.mouseInfo()
